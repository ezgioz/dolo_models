# %%
from dolo import *
from matplotlib import pyplot as plt

# %%
model = yaml_import("consumption_savings_less_simple.yaml")

# %%
dr = time_iteration(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-338c2c4d1d05> in <module>
# ----> 1 dr = time_iteration(model)
#
# c:\users\e.ozsogut\econforge\dolo\dolo\algos\time_iteration.py in time_iteration(model, initial_guess, dprocess, with_complementarities, verbose, grid, maxit, inner_maxit, tol, hook, details)
#      74
#      75     if dprocess is None:
# ---> 76         dprocess = model.exogenous.discretize()
#      77
#      78     n_ms = dprocess.n_nodes() # number of exogenous states
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\model.py in exogenous(self)
#     333     def exogenous(self):
#     334         if self.__exogenous__ is None:
# --> 335             self.__exogenous__ = super(self.__class__, self).get_exogenous()
#     336         return self.__exogenous__
#     337
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\model.py in get_exogenous(self)
#     196         else:
#     197             raise Exception("Unknown exogenous type {}.".format(type))
# --> 198         d = exog.eval(d=calibration)
#     199         return d
#     200
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\language.py in eval(self, d)
#      35         from dolo.compiler.symbolic_eval import NumericEval
#      36         ne = NumericEval(d)
# ---> 37         args = ne.eval_dict(self)
#      38         obj = self.baseclass(**args)
#      39         return obj
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in eval_dict(self, d)
#      70     def eval_dict(self, d):
#      71
# ---> 72         return {k: self.eval(e) for k, e in d.items()}
#      73
#      74     def eval_ordereddict(self, s):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in <dictcomp>(.0)
#      70     def eval_dict(self, d):
#      71
# ---> 72         return {k: self.eval(e) for k, e in d.items()}
#      73
#      74     def eval_ordereddict(self, s):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in eval(self, struct)
#      38             raise Exception("Unknown type {}".format(method_name))
#      39
# ---> 40         return fun(struct)
#      41
#      42     def eval_scalarfloat(self, s):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in eval_commentedseq(self, s)
#      82
#      83     def eval_commentedseq(self, s):
# ---> 84         return self.eval_list(s)
#      85
#      86     def eval_ndarray(self, array_in):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in eval_list(self, l)
#      66     def eval_list(self, l):
#      67
# ---> 68         return [self.eval(e) for e in l]
#      69
#      70     def eval_dict(self, d):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in <listcomp>(.0)
#      66     def eval_list(self, l):
#      67
# ---> 68         return [self.eval(e) for e in l]
#      69
#      70     def eval_dict(self, d):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in eval(self, struct)
#      38             raise Exception("Unknown type {}".format(method_name))
#      39
# ---> 40         return fun(struct)
#      41
#      42     def eval_scalarfloat(self, s):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in eval_commentedseq(self, s)
#      82
#      83     def eval_commentedseq(self, s):
# ---> 84         return self.eval_list(s)
#      85
#      86     def eval_ndarray(self, array_in):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in eval_list(self, l)
#      66     def eval_list(self, l):
#      67
# ---> 68         return [self.eval(e) for e in l]
#      69
#      70     def eval_dict(self, d):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in <listcomp>(.0)
#      66     def eval_list(self, l):
#      67
# ---> 68         return [self.eval(e) for e in l]
#      69
#      70     def eval_dict(self, d):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in eval(self, struct)
#      38             raise Exception("Unknown type {}".format(method_name))
#      39
# ---> 40         return fun(struct)
#      41
#      42     def eval_scalarfloat(self, s):
#
# c:\users\e.ozsogut\econforge\dolo\dolo\compiler\symbolic_eval.py in eval_str(self, s)
#      62
#      63         # not safe
# ---> 64         return eval(s, self.d)
#      65
#      66     def eval_list(self, l):
#
# <string> in <module>
#
# NameError: name 'σ' is not defined

# %% [markdown]
# One can also try the faster version

# %% [markdown]
# ## Stochastic Simulations

# %%
# Shocks are discretized as a markov chain by default:
dp = model.exogenous.discretize()
sim_shock = dp.simulate(10, 100, i0=1)
for i in range(10):
    plt.plot(sim_shock[:,i,0], color='red', alpha=0.5)

# %%
sim = simulate(model, dr, i0=1, N=100)
# Out:
# YAMLLoadWarning:C:\Users\e.ozsogut\AppData\Local\Continuum\anaconda3\lib\site-packages\dask\config.py:168
#     calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# YAMLLoadWarning:C:\Users\e.ozsogut\AppData\Local\Continuum\anaconda3\lib\site-packages\distributed\config.py:20
#     calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
plt.subplot(121)
for i in range(10):
    plt.plot(sim.sel(N=i,V='c'), color='red', alpha=0.5)
plt.ylabel("$c_t$")
plt.xlabel("$t$")
plt.subplot(122)
for i in range(10):
    plt.plot(sim.sel(N=i,V='w'), color='red', alpha=0.5)
plt.xlabel("$t$")
plt.ylabel("$w_t$")

plt.tight_layout()

# %% [markdown]
# ## Ergodic distribution

# %%
sim_long = simulate(model, dr, i0=1, N=1000, T=200)

# %%
import seaborn
seaborn.distplot(sim_long.sel(T=199, V='w'))
plt.xlabel("$w$")
# Out:
# Text(0.5, 0, '$w$')

# %% [markdown]
# ## Plotting Decision Rule

# %%
tab = tabulate(model, dr,'w')

# %%
from matplotlib import pyplot as plt

# %%
stable_wealth = model.eval_formula('1/r+(1-1/r)*w(0)', tab)
plt.plot(tab['w'], tab['w'],color='black', linestyle='--')
plt.plot(tab['w'], stable_wealth,color='black', linestyle='--')
plt.plot(tab['w'], tab['c'])
plt.xlabel("w_t")
plt.ylabel("c_t")
plt.grid()
